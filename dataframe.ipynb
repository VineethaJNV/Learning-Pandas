# %%
import pandas as pd

# %%
info = {
    "name":["vinee", "vani", "yash"],
    "cgpa" : [9.0, 9.2, 10]
}

df = pd.DataFrame(info)
print(df, type(df))

print(df.index)
print(df.columns)
# Out:
#     name  cgpa
# 0  vinee   9.0
# 1   vani   9.2
# 2   yash  10.0 <class 'pandas.core.frame.DataFrame'>
# RangeIndex(start=0, stop=3, step=1)
# Index(['name', 'cgpa'], dtype='object')

# %%
df = pd.DataFrame([["vinee",24],["vani", 24],["vpr", 20]], columns=["Name", "age"])
print(df)
# Out:
#     Name  age
# 0  vinee   24
# 1   vani   24
# 2    vpr   20

# %%
import numpy as np

np_arr = np.array([[1, 2, 3], [2, 3, 4], [4, 5,6]])
df=pd.DataFrame(np_arr, columns=["A", "B", "C"])
print(df)
# Out:
#    A  B  C
# 0  1  2  3
# 1  2  3  4
# 2  4  5  6
