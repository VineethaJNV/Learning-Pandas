# %%
import pandas as pd

# %%
#Data types
df = pd.read_csv("raw_data.csv")

# %%
df.dtypes
# Out:
# id           int64
# name        object
# age        float64
# country     object
# gender      object
# dtype: object

# %%
#Let's convert age from floaat to int
df2 = df.copy()
df2 = df2.fillna(0)
df2 = df2["age"].astype("int64").copy()

# %%
df2
# Out:
# 0     29
# 1     29
# 2      0
# 3      0
# 4     34
# 5     27
# 6     45
# 7     38
# 8     29
# 9      0
# 10    31
# Name: age, dtype: int64

# %%
df2.dtypes
# Out:
# dtype('int64')

# %%
date_time = pd.Series([pd.to_datetime("2025-12-14")])
print(type(date_time))
print(date_time.dtype)
# Out:
# <class 'pandas.core.series.Series'>
# datetime64[ns]
