# %%
import pandas as pd

# %%
df = pd.read_csv("globalAirQuality.csv")
print(df)
# Out:
#                         timestamp country      city  latitude  longitude  \
# 0      2025-11-04 18:25:17.554219      US  New York    40.713    -74.006
# 1      2025-11-04 19:25:17.554219      US  New York    40.713    -74.006
# 2      2025-11-04 20:25:17.554219      US  New York    40.713    -74.006
# 3      2025-11-04 21:25:17.554219      US  New York    40.713    -74.006
# 4      2025-11-04 22:25:17.554219      US  New York    40.713    -74.006
# ...                           ...     ...       ...       ...        ...
# 17995  2025-11-19 13:25:17.554219      CH    Zurich    47.377      8.542
# 17996  2025-11-19 14:25:17.554219      CH    Zurich    47.377      8.542
# 17997  2025-11-19 15:25:17.554219      CH    Zurich    47.377      8.542
# 17998  2025-11-19 16:25:17.554219      CH    Zurich    47.377      8.542
# 17999  2025-11-19 17:25:17.554219      CH    Zurich    47.377      8.542
#
#          pm25     pm10     no2    so2      o3     co  aqi  temperature  \
# ...

# %%
df[df["aqi"] > 190]
# Out:
#                         timestamp country          city  latitude  longitude  \
# 112    2025-11-09 10:25:17.554219      US      New York    40.713    -74.006
# 745    2025-11-05 19:25:17.554219      GB        London    51.507     -0.128
# 3115   2025-11-14 13:25:17.554219      MX   Mexico City    19.433    -99.133
# 3786   2025-11-12 12:25:17.554219      AR  Buenos Aires   -34.604    -58.382
# 6747   2025-11-15 21:25:17.554219      IN        Mumbai    19.076     72.878
# 6783   2025-11-17 09:25:17.554219      IN        Mumbai    19.076     72.878
# 7024   2025-11-12 10:25:17.554219      IN         Delhi    28.704     77.102
# 8841   2025-11-13 03:25:17.554219      JP         Osaka    34.694    135.502
# 8941   2025-11-17 07:25:17.554219      JP         Osaka    34.694    135.502
# 10221  2025-11-10 15:25:17.554219      HK     Hong Kong    22.319    114.169
# 10463  2025-11-05 17:25:17.554219      SG     Singapore     1.352    103.820
# ...

# %%
df[(df["aqi"] > 100) & (df["country"] == "IN")]
# Out:
#                        timestamp country     city  latitude  longitude  \
# 6483  2025-11-04 21:25:17.554219      IN   Mumbai    19.076     72.878
# 6485  2025-11-04 23:25:17.554219      IN   Mumbai    19.076     72.878
# 6488  2025-11-05 02:25:17.554219      IN   Mumbai    19.076     72.878
# 6489  2025-11-05 03:25:17.554219      IN   Mumbai    19.076     72.878
# 6490  2025-11-05 04:25:17.554219      IN   Mumbai    19.076     72.878
# ...                          ...     ...      ...       ...        ...
# 8272  2025-11-19 10:25:17.554219      IN  Chennai    13.083     80.271
# 8274  2025-11-19 12:25:17.554219      IN  Chennai    13.083     80.271
# 8276  2025-11-19 14:25:17.554219      IN  Chennai    13.083     80.271
# 8278  2025-11-19 16:25:17.554219      IN  Chennai    13.083     80.271
# 8279  2025-11-19 17:25:17.554219      IN  Chennai    13.083     80.271
#
#         pm25     pm10     no2    so2      o3     co  aqi  temperature  \
# ...

# %%
df[df["aqi"] > 0][["country", "city", "temperature"]]
# Out:
#       country      city  temperature
# 0          US  New York       18.504
# 1          US  New York        5.838
# 2          US  New York       31.833
# 3          US  New York       23.140
# 4          US  New York       13.632
# ...       ...       ...          ...
# 17995      CH    Zurich        7.079
# 17996      CH    Zurich       28.734
# 17997      CH    Zurich       21.951
# 17998      CH    Zurich       24.042
# 17999      CH    Zurich        8.529
#
# [18000 rows x 3 columns]

# %% [markdown]
# ## Pandas preserves the original lables of the rows even after filtering
# ## After filtering, the labels are different and the index is different because, all the labels are not filtered and few may be missing, So, iloc[] and loc[] will not work the same anymore on the filtered data

# %%
filtered = df[(df["aqi"] > 100) & (df["country"] == "IN") & (df["city"] == "Delhi")][["city", "country", "temperature", "aqi"]]
# print(filtered)
print(filtered.loc[6841])
print(filtered.iloc[0])
# Out:
# city            Delhi
# country            IN
# temperature    23.468
# aqi               133
# Name: 6841, dtype: object
# city            Delhi
# country            IN
# temperature    23.468
# aqi               133
# Name: 6841, dtype: object
